# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

project_path = Path("/content/drive/MyDrive/UM_WQF7023/MRDRP-main")

# Change this according to the trait
target_folder = project_path / "exposures" / "IGF1"
#target_folder = project_path / "outcome" / "endometrial_cancer"

target_folder.mkdir(parents=True, exist_ok=True)

print("Target folder:", target_folder)
print("Exists:", target_folder.exists())
# Out:
# Target folder: /content/drive/MyDrive/UM_WQF7023/MRDRP-main/exposures/IGF1
# Exists: True

# %%
url = "http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/GCST90161001-GCST90162000/GCST90161219/GCST90161219_buildGRCh37.tsv"

output_path = target_folder / "GCST90161219_buildGRCh37.tsv"

# !wget -c "{url}" -O "{output_path}"

print("Downloaded to:", output_path)
# Out:
# --2026-05-11 16:55:28--  http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/GCST90161001-GCST90162000/GCST90161219/GCST90161219_buildGRCh37.tsv
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# Downloaded to: /content/drive/MyDrive/UM_WQF7023/MRDRP-main/exposures/IGF1/GCST90161219_buildGRCh37.tsv
